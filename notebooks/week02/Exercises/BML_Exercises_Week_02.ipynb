# %%
import numpy as np
import matplotlib.pyplot as plt
import preliz as pz

# %% [markdown]
# # The Beta Distribution
#
# ![The Beta Distribution](The-Beta-Distribution.png)
#
# $$
# \begin{align}
# E[\pi] &= \frac{\alpha}{\alpha + \beta}\\
# E[\pi] \cdot (\alpha + \beta) &= \alpha\\
# E[\pi] \cdot \alpha + E[\pi] \cdot \beta &= \alpha\\
# E[\pi] \cdot \beta &= \alpha - E[\pi] \cdot \alpha\\
# E[\pi] \cdot \beta &= \alpha (1 - E[\pi])\\
# \frac{E[\pi]}{1 - E[\pi]} &= \frac{\alpha}{\beta}\\
# \frac{E[\pi]}{1 - E[\pi]} \cdot \beta &= \alpha
# \end{align}
# $$
#
# $$
# \begin{align}
# \alpha &= \frac{E[\pi]}{1 - E[\pi]} \cdot \beta\\
# \alpha &= q \cdot \beta \quad \text{for } q = \frac{E[\pi]}{1 - E[\pi]}\\
# \end{align}
# $$
#
# $$
# \begin{align}
# Var[\pi] &= \frac{\alpha\beta}{(\alpha+\beta)^2\;(\alpha+\beta+1)}\\
# Var[\pi] & = \frac{q \cdot \beta \cdot \beta}{(q \cdot \beta + \beta)^{2} \cdot (q \cdot \beta + \beta + 1)}\\
# Var[\pi] &= \frac{q \cdot \beta^{2}}{(q+1)^{2} \cdot \beta^{2} \cdot [(q+1) \cdot \beta + 1]}\\
# Var[\pi] &= \frac{q}{(q+1)^{2} \cdot [(q+1) \cdot \beta + 1]}\\
# [(q+1) \cdot \beta + 1] &= \frac{q}{(q+1)^{2} \cdot Var[\pi]}\\
# (q+1) \cdot \beta &= \frac{q}{(q+1)^{2} \cdot Var[\pi]} - 1\\
# \beta &= \left[ \frac{q}{(q+1)^{2} \cdot Var[\pi]} - 1 \right] : (q+1)\\
#       &= \left[ \frac{q}{(q+1)^2 \cdot Var[\pi]} - 1 \right] \cdot \frac{1}{q+1}\\
#       &= \frac{q}{(q+1)^3 \cdot Var[\pi]} - \frac{1}{q+1}
# \end{align}
# $$

# %% [markdown]
# # Interactive Beta Distribution Plot using PreliZ

# %%
pz.Beta( 10, 10 ).plot_interactive( figsize=(12,3) )
# Out:
# interactive(children=(FloatSlider(value=10.0, description='alpha (0, inf)', max=110.0, min=2.220446049250313e-…

# %% [markdown]
# # Exercise 1
#
# Tune a $Beta(\alpha, \beta)$ model that accurately reflects the given prior information and visualize it.
#
# **Hint:** Often you can constrain the possible values for $\alpha$ and $\beta$ using a given expectation or variance (see beta distribution's expectation or variance above).

# %% [markdown]
# $$
# \begin{align}
# E[\pi] &= \frac{\alpha}{\alpha + \beta}\\
# E[\pi] \cdot (\alpha + \beta) &= \alpha\\
# E[\pi] \cdot \alpha + E[\pi] \cdot \beta &= \alpha\\
# E[\pi] \cdot \beta &= \alpha - E[\pi] \cdot \alpha\\
# E[\pi] \cdot \beta &= \alpha (1 - E[\pi])\\
# \frac{E[\pi]}{1 - E[\pi]} &= \frac{\alpha}{\beta}
# \end{align}
# $$

# %% [markdown]
# a) Your friend applied to a job and tells you: "I think I have a 40% chance of getting the job, but I'm pretty unsure". When pressed further, they put their chances between 20% and 60%.

# %% [markdown]
# $$
# \begin{align}
# \frac{\alpha}{\beta} &= \frac{0.4}{1 - 0.4}\\
# \alpha &= \frac{0.4}{0.6} \cdot \beta\\
# \alpha &= \frac{0.4}{0.6} \cdot \beta\\
# \alpha &= \frac{2}{3} \cdot \beta
# \end{align}
# $$

# %%
beta = 15
alpha = 2/3 * beta

pz.Beta(alpha, beta).plot_pdf(figsize=(12,3))
# Out:
# <Axes: >

# %% [markdown]
# b) A scientist has created a new test for a rare disease. They expect that the test is accurate 80% of the time with a variance of $0.005$

# %% [markdown]
# $$
# \begin{align}
# \frac{\alpha}{\beta} &=\frac{E[\pi]}{1 - E[\pi]}\\
#                     &= \frac{0.8}{1-0.8}\\
# \alpha &= \frac{0.8}{0.2} \cdot \beta\\
# \alpha &= 4\beta
# \end{align}
# $$
#
# $$
# \begin{align}
# Var[\pi] &= \frac{\alpha\beta}{(\alpha + \beta)^2 \cdot (\alpha + \beta + 1)}\\
#          &= \frac{4\beta \cdot \beta}{(4\beta + \beta)^{2} (4\beta + \beta + 1)}\\
#          &= \frac{4\beta^{2}}{(5\beta)^{2} \cdot (5\beta + 1)}\\
#          &= \frac{4\beta^2}{25\beta^{2} \cdot (5\beta + 1)}\\
#          &= \frac{4}{25 \cdot (5\beta + 1)}\\
#          &= \frac{4}{125\beta + 25}\\
# \\
# 0.005 &= \frac{4}{125\beta + 25}\\
# (125\beta + 25) * 0.005 &= 4\\
# \beta &= \left[ \frac{4}{0.005} - 25 \right] : 125\\
#       &= 6.2\\
# \end{align}
# $$

# %%
beta = 6.2
alpha = 4 * beta

pz.Beta(alpha, beta).plot_pdf(figsize=(12, 3))
# Out:
# <Axes: >

# %% [markdown]
# c) Another scientist in the same field claims that he expects the same accuracy, however ten times larger variance of $0.05$. Can the beta distribution model this prior expectation as well?

# %%
beta = (4 / 0.05 - 25) / 125
alpha = 4 * beta

pz.Beta(alpha, beta).plot_pdf(figsize=(12, 3))
# Out:
# <Axes: >

# %% [markdown]
# Nope! The beta distribution is unable to model this prior expectation. We would need to use something else for this task.

# %% [markdown]
# d) Your Aunt Jo is a successful mushroom hunter. She boasts: I expect to find enough mushrooms to feed myself and my co-workers at the auto-repair shop 90% of the time, but if I had to give you a likely range it would be between 85% and 100% of the time".

# %% [markdown]
# Given:
#
# $$
# \begin{align}
# \mathbb{E}[\pi] &= 0.9\\
# \sigma &= \frac{1.0 - 0.85}{2} = 0.075\\
# \mathrm{Var}[\pi] &=\sigma^2 = 0.075^2 = 0.005625
# \end{align}
# $$
#
# Then:
#
# $$
# \begin{align}
# \frac{\alpha}{\beta} &= \frac{\mathbb{E}[\pi]}{1-\mathbb{E}[\pi]} = \frac{0.9}{0.1} \\
# \alpha &= \frac{0.9}{0.1} \cdot \beta\\
# \alpha &= 9 \cdot \beta
# \end{align}
# $$
#
# $$
# \begin{align}
# \mathrm{Var}[\pi] &= \frac{\alpha \cdot \beta}{(\alpha + \beta)^{2} \cdot (\alpha + \beta + 1)}\\
# 0.005625 &= \frac{9\beta \cdot \beta}{(9\beta + \beta)^{2} \cdot (9\beta + \beta + 1)} = \frac{9\beta^{2}}{10^{2} \cdot \beta^{2} \cdot (10\beta + 1)}\\
# 0.005625 & = \frac{9}{10^{3} \cdot \beta + 10^{2}}\\
# 0.005625 &= \frac{9}{10^{3} \beta + 10^{2}}\\
# 10^{3} \beta + 10^{2} &= \frac{9}{0.005625}\\
# 10^{3} \beta &= \frac{9}{0.005625} + 10^{2}\\
# \beta &= [\frac{9}{0.005625} + 100] : 10^{3} = 1.7
# \end{align}
# $$

# %%
beta = 1.7
alpha = 9 * beta

pz.Beta(alpha, beta).plot_pdf(figsize=(12, 3))
# Out:
# <Axes: >

# %% [markdown]
# e) Sal (who is a touch hyperbolic) just interviewed for a job, and doesn't know how to describe their chances of getting an offer. The say, "I couldn't read my interviewer's expression! I either really impressed them and the are absolutely going to hiere me, or I made a terrible impression and they are burning my resumé as we speak.

# %% [markdown]
# This calls for a beta distribution with $\alpha, \beta < 1$ !

# %%
pz.Beta(0.75, 0.75).plot_pdf(figsize=(12,3))
# Out:
# <Axes: >

# %% [markdown]
# # Exercise 2
#
# $$
# \begin{align}
# \alpha &= \frac{E[\pi]}{1-E[\pi]} \cdot \beta \\
# Var[\pi] &= \frac{\alpha \cdot \beta}{(\alpha + \beta)^{2} \cdot (\alpha + \beta + 1)}\\
# \end{align}
# $$
#
# a) I would choose the Beta-binominal conjugate family because we are dealing with a binary problem here.
#
# Priors of Heidi:
#
# $$
# \begin{align}
# E[\pi_{Heidi}] &= 0.1\\
# \sigma_{Heidi} &= \frac{0.1}{2} = 0.05\\
# Var[\pi_{Heidi}] &= (\sigma_{Heidi})^2 = 0.0025\\
# \end{align}
# $$
#
# $$
# \begin{align}
# \alpha_{Heidi} &= \frac{0.1}{1-0.1} \cdot \beta_{Heidi} = \frac{1}{9} \cdot \beta_{Heidi}\\
# q_{Heidi} &= \frac{1}{9}\\
# \beta_{Heidi} &= \frac{q}{(q+1)^3*Var[\pi_{Heidi}]} - \frac{1}{q+1}\\
# &= \frac{\frac{1}{9}}{(\frac{1}{9}+1)^3*0.0025} - \frac{1}{\frac{1}{9}+1}\\
# &= 31.5
# \end{align}
# $$

# %%
beta_heidi = 31.5
alpha_heidi = 1/9 * beta_heidi

pz.Beta(alpha_heidi, beta_heidi).plot_pdf(figsize=(12,3))
# Out:
# <Axes: >

# %% [markdown]
# and Peter. Because he is less sure, we'll just assume $\sigma_{Peter} = 2 * \sigma_{Heidi}$:
#
# $$
# \begin{align}
# E[\pi_{Peter}] &= 0.5\\
# \sigma_{Peter} &= \frac{0.20}{2} = 0.1\\
# Var[\pi_{Peter}] &= (\sigma_{Peter})^2 = 0.01\\
# \alpha_{Peter} &= \frac{E[\pi_{Peter}]}{1 - E[\pi_{Peter}]} \cdot \beta_{Peter}\\
#                &= 1 \cdot \beta_{Peter}\\
# q_{Peter} &= \frac{1}{1} = 1\\
# \beta_{Peter} &= \frac{q}{(q+1)^3*Var[\pi_{Peter}]} - \frac{1}{q+1}\\
# &= \frac{1}{(1+1)^3*0.01} - \frac{1}{1+1}\\
# &= \frac{1}{8*0.01} - \frac{1}{2}\\
# &= 12
# \end{align}
# $$

# %%
beta_peter = 12
alpha_peter = beta_peter

pz.Beta(alpha_peter, beta_peter).plot_pdf(figsize=(12,3))
# Out:
# <Axes: >

# %% [markdown]
# b) Compute the parameters of Heidi and Peter's posterior distributions if Peter is the onluy one out of 6 people who mixes their apple puré with the rest. How do their opinions change in the light of the data? Compare their prior distributions.

# %% [markdown]
# **Heidi's change in belief**

# %%
n = 6
k = 1

post_alpha_heidi = alpha_heidi + k
post_beta_heidi = beta_heidi + n - k

prior_heidi = pz.Beta(alpha_heidi, beta_heidi)
post_heidi = pz.Beta(post_alpha_heidi, post_beta_heidi)

prior_heidi.plot_pdf(figsize=(12, 3))
print(f"Prior (mean = {prior_heidi.mean():.4f}")
post_heidi.plot_pdf(figsize=(12, 3))
print(f"Post (mean = {post_heidi.mean():.4f})")
# Out:
# Prior (mean = 0.1000
# Post (mean = 0.1098)

# %% [markdown]
# **Peter's change in belief**

# %%
n = 6
k = 1

post_alpha_peter = alpha_peter + k
post_beta_peter = beta_peter + n - k

prior_peter = pz.Beta(alpha_peter, beta_peter)
post_peter = pz.Beta(post_alpha_peter, post_beta_peter)

prior_peter.plot_pdf(figsize=(12, 3))
print(f"Prior (mean = {prior_peter.mean():.4f})")
post_peter.plot_pdf(figsize=(12, 3))
print(f"Post (mean = {post_peter.mean():.4f})")
# Out:
# Prior (mean = 0.5000)
# Post (mean = 0.4333)

# %% [markdown]
# c) How much would it change for Heidi's posterior opinion if instead of just Peter all of the 6 participants would have mixed? Could Peter convince here with this data? If no, how many people would they have needed to be (all mixing) to increase the expectation of Heidi's opinion to at least 50%?

# %%
n = 6
k = 1

prior_heidi = pz.Beta(alpha_heidi, beta_heidi)
prior_heidi.plot_pdf(figsize=(12, 3))
print(f"Prior: {prior_heidi.mean():.4f}")

for k in range(n+1):
    post_alpha_heidi = alpha_heidi + k
    post_beta_heidi = beta_heidi + n - k

    post_heidi = pz.Beta(post_alpha_heidi, post_beta_heidi)
    post_heidi.plot_pdf(figsize=(12, 3))
    print(f"Post ({n} choose {k}, mean = {post_heidi.mean():.4f})")
# Out:
# Prior: 0.1000
# Post (6 choose 0, mean = 0.0854)
# Post (6 choose 1, mean = 0.1098)
# Post (6 choose 2, mean = 0.1341)
# Post (6 choose 3, mean = 0.1585)
# Post (6 choose 4, mean = 0.1829)
# Post (6 choose 5, mean = 0.2073)
# Post (6 choose 6, mean = 0.2317)

# %% [markdown]
# Heidi is not convinced: Even if all 6/6 participants would mix, she would still believe that approximately 23.17% out of all people mix apple puré.

# %%
prior_heidi = pz.Beta(alpha_heidi, beta_heidi)
prior_heidi.plot_pdf(figsize=(12, 3), legend=f"Prior: {prior_heidi.mean():.4f}")

mean = prior_heidi.mean()

n = 1
k = 1

while mean < 0.5:
    post_alpha_heidi = alpha_heidi + k
    post_beta_heidi = beta_heidi + n - k

    post_heidi = pz.Beta(post_alpha_heidi, post_beta_heidi)
    mean = post_heidi.mean()

    post_heidi.plot_pdf(figsize=(12, 3))
    print(f"Post ({n} choose {k}, mean = {mean:.4f})")

    if k == n:
        n += 1
        k = 1
    elif k < n:
        k += 1
# Out:
# Post (1 choose 1, mean = 0.1250)
# Post (2 choose 1, mean = 0.1216)
# Post (2 choose 2, mean = 0.1486)
# Post (3 choose 1, mean = 0.1184)
# Post (3 choose 2, mean = 0.1447)
# Post (3 choose 3, mean = 0.1711)
# Post (4 choose 1, mean = 0.1154)
# Post (4 choose 2, mean = 0.1410)
# Post (4 choose 3, mean = 0.1667)
# Post (4 choose 4, mean = 0.1923)
# Post (5 choose 1, mean = 0.1125)
# Post (5 choose 2, mean = 0.1375)
# Post (5 choose 3, mean = 0.1625)
# Post (5 choose 4, mean = 0.1875)
# Post (5 choose 5, mean = 0.2125)
# Post (6 choose 1, mean = 0.1098)
# Post (6 choose 2, mean = 0.1341)
# Post (6 choose 3, mean = 0.1585)
# Post (6 choose 4, mean = 0.1829)
# Post (6 choose 5, mean = 0.2073)
# Post (6 choose 6, mean = 0.2317)
# Post (7 choose 1, mean = 0.1071)
# Post (7 choose 2, mean = 0.1310)
# Post (7 choose 3, mean = 0.1548)
# Post (7 choose 4, mean = 0.1786)
# Post (7 choose 5, mean = 0.2024)
# Post (7 choose 6, mean = 0.2262)
# Post (7 choose 7, mean = 0.2500)
# Post (8 choose 1, mean = 0.1047)
# Post (8 choose 2, mean = 0.1279)
# Post (8 choose 3, mean = 0.1512)
# Post (8 choose 4, mean = 0.1744)
# Post (8 choose 5, mean = 0.1977)
# Post (8 choose 6, mean = 0.2209)
# Post (8 choose 7, mean = 0.2442)
# Post (8 choose 8, mean = 0.2674)
# Post (9 choose 1, mean = 0.1023)
# Post (9 choose 2, mean = 0.1250)
# Post (9 choose 3, mean = 0.1477)
# Post (9 choose 4, mean = 0.1705)
# Post (9 choose 5, mean = 0.1932)
# Post (9 choose 6, mean = 0.2159)
# Post (9 choose 7, mean = 0.2386)
# Post (9 choose 8, mean = 0.2614)
# Post (9 choose 9, mean = 0.2841)
# Post (10 choose 1, mean = 0.1000)
# Post (10 choose 2, mean = 0.1222)
# Post (10 choose 3, mean = 0.1444)
# Post (10 choose 4, mean = 0.1667)
# Post (10 choose 5, mean = 0.1889)
# Post (10 choose 6, mean = 0.2111)
# Post (10 choose 7, mean = 0.2333)
# Post (10 choose 8, mean = 0.2556)
# Post (10 choose 9, mean = 0.2778)
# Post (10 choose 10, mean = 0.3000)
# Post (11 choose 1, mean = 0.0978)
# Post (11 choose 2, mean = 0.1196)
# Post (11 choose 3, mean = 0.1413)
# Post (11 choose 4, mean = 0.1630)
# Post (11 choose 5, mean = 0.1848)
# Post (11 choose 6, mean = 0.2065)
# Post (11 choose 7, mean = 0.2283)
# Post (11 choose 8, mean = 0.2500)
# Post (11 choose 9, mean = 0.2717)
# Post (11 choose 10, mean = 0.2935)
# Post (11 choose 11, mean = 0.3152)
# Post (12 choose 1, mean = 0.0957)
# Post (12 choose 2, mean = 0.1170)
# Post (12 choose 3, mean = 0.1383)
# Post (12 choose 4, mean = 0.1596)
# Post (12 choose 5, mean = 0.1809)
# Post (12 choose 6, mean = 0.2021)
# Post (12 choose 7, mean = 0.2234)
# Post (12 choose 8, mean = 0.2447)
# Post (12 choose 9, mean = 0.2660)
# Post (12 choose 10, mean = 0.2872)
# Post (12 choose 11, mean = 0.3085)
# Post (12 choose 12, mean = 0.3298)
# Post (13 choose 1, mean = 0.0938)
# Post (13 choose 2, mean = 0.1146)
# Post (13 choose 3, mean = 0.1354)
# Post (13 choose 4, mean = 0.1562)
# Post (13 choose 5, mean = 0.1771)
# Post (13 choose 6, mean = 0.1979)
# Post (13 choose 7, mean = 0.2188)
# Post (13 choose 8, mean = 0.2396)
# Post (13 choose 9, mean = 0.2604)
# Post (13 choose 10, mean = 0.2812)
# Post (13 choose 11, mean = 0.3021)
# Post (13 choose 12, mean = 0.3229)
# Post (13 choose 13, mean = 0.3438)
# Post (14 choose 1, mean = 0.0918)
# Post (14 choose 2, mean = 0.1122)
# Post (14 choose 3, mean = 0.1327)
# Post (14 choose 4, mean = 0.1531)
# Post (14 choose 5, mean = 0.1735)
# Post (14 choose 6, mean = 0.1939)
# Post (14 choose 7, mean = 0.2143)
# Post (14 choose 8, mean = 0.2347)
# Post (14 choose 9, mean = 0.2551)
# Post (14 choose 10, mean = 0.2755)
# Post (14 choose 11, mean = 0.2959)
# Post (14 choose 12, mean = 0.3163)
# Post (14 choose 13, mean = 0.3367)
# Post (14 choose 14, mean = 0.3571)
# Post (15 choose 1, mean = 0.0900)
# Post (15 choose 2, mean = 0.1100)
# Post (15 choose 3, mean = 0.1300)
# Post (15 choose 4, mean = 0.1500)
# Post (15 choose 5, mean = 0.1700)
# Post (15 choose 6, mean = 0.1900)
# Post (15 choose 7, mean = 0.2100)
# Post (15 choose 8, mean = 0.2300)
# Post (15 choose 9, mean = 0.2500)
# Post (15 choose 10, mean = 0.2700)
# Post (15 choose 11, mean = 0.2900)
# Post (15 choose 12, mean = 0.3100)
# Post (15 choose 13, mean = 0.3300)
# Post (15 choose 14, mean = 0.3500)
# Post (15 choose 15, mean = 0.3700)
# Post (16 choose 1, mean = 0.0882)
# Post (16 choose 2, mean = 0.1078)
# Post (16 choose 3, mean = 0.1275)
# Post (16 choose 4, mean = 0.1471)
# Post (16 choose 5, mean = 0.1667)
# Post (16 choose 6, mean = 0.1863)
# Post (16 choose 7, mean = 0.2059)
# Post (16 choose 8, mean = 0.2255)
# Post (16 choose 9, mean = 0.2451)
# Post (16 choose 10, mean = 0.2647)
# Post (16 choose 11, mean = 0.2843)
# Post (16 choose 12, mean = 0.3039)
# Post (16 choose 13, mean = 0.3235)
# Post (16 choose 14, mean = 0.3431)
# Post (16 choose 15, mean = 0.3627)
# Post (16 choose 16, mean = 0.3824)
# Post (17 choose 1, mean = 0.0865)
# Post (17 choose 2, mean = 0.1058)
# Post (17 choose 3, mean = 0.1250)
# Post (17 choose 4, mean = 0.1442)
# Post (17 choose 5, mean = 0.1635)
# Post (17 choose 6, mean = 0.1827)
# Post (17 choose 7, mean = 0.2019)
# Post (17 choose 8, mean = 0.2212)
# Post (17 choose 9, mean = 0.2404)
# Post (17 choose 10, mean = 0.2596)
# Post (17 choose 11, mean = 0.2788)
# Post (17 choose 12, mean = 0.2981)
# Post (17 choose 13, mean = 0.3173)
# Post (17 choose 14, mean = 0.3365)
# Post (17 choose 15, mean = 0.3558)
# Post (17 choose 16, mean = 0.3750)
# Post (17 choose 17, mean = 0.3942)
# Post (18 choose 1, mean = 0.0849)
# Post (18 choose 2, mean = 0.1038)
# Post (18 choose 3, mean = 0.1226)
# Post (18 choose 4, mean = 0.1415)
# Post (18 choose 5, mean = 0.1604)
# Post (18 choose 6, mean = 0.1792)
# Post (18 choose 7, mean = 0.1981)
# Post (18 choose 8, mean = 0.2170)
# Post (18 choose 9, mean = 0.2358)
# Post (18 choose 10, mean = 0.2547)
# Post (18 choose 11, mean = 0.2736)
# Post (18 choose 12, mean = 0.2925)
# Post (18 choose 13, mean = 0.3113)
# Post (18 choose 14, mean = 0.3302)
# Post (18 choose 15, mean = 0.3491)
# Post (18 choose 16, mean = 0.3679)
# Post (18 choose 17, mean = 0.3868)
# Post (18 choose 18, mean = 0.4057)
# Post (19 choose 1, mean = 0.0833)
# Post (19 choose 2, mean = 0.1019)
# Post (19 choose 3, mean = 0.1204)
# Post (19 choose 4, mean = 0.1389)
# Post (19 choose 5, mean = 0.1574)
# Post (19 choose 6, mean = 0.1759)
# Post (19 choose 7, mean = 0.1944)
# Post (19 choose 8, mean = 0.2130)
# Post (19 choose 9, mean = 0.2315)
# Post (19 choose 10, mean = 0.2500)
# Post (19 choose 11, mean = 0.2685)
# Post (19 choose 12, mean = 0.2870)
# Post (19 choose 13, mean = 0.3056)
# Post (19 choose 14, mean = 0.3241)
# Post (19 choose 15, mean = 0.3426)
# Post (19 choose 16, mean = 0.3611)
# Post (19 choose 17, mean = 0.3796)
# Post (19 choose 18, mean = 0.3981)
# Post (19 choose 19, mean = 0.4167)
# Post (20 choose 1, mean = 0.0818)
# Post (20 choose 2, mean = 0.1000)
# Post (20 choose 3, mean = 0.1182)
# Post (20 choose 4, mean = 0.1364)
# Post (20 choose 5, mean = 0.1545)
# Post (20 choose 6, mean = 0.1727)
# Post (20 choose 7, mean = 0.1909)
# Post (20 choose 8, mean = 0.2091)
# Post (20 choose 9, mean = 0.2273)
# Post (20 choose 10, mean = 0.2455)
# Post (20 choose 11, mean = 0.2636)
# Post (20 choose 12, mean = 0.2818)
# Post (20 choose 13, mean = 0.3000)
# Post (20 choose 14, mean = 0.3182)
# Post (20 choose 15, mean = 0.3364)
# Post (20 choose 16, mean = 0.3545)
# Post (20 choose 17, mean = 0.3727)
# Post (20 choose 18, mean = 0.3909)
# Post (20 choose 19, mean = 0.4091)
# Post (20 choose 20, mean = 0.4273)
# Post (21 choose 1, mean = 0.0804)
# Post (21 choose 2, mean = 0.0982)
# Post (21 choose 3, mean = 0.1161)
# Post (21 choose 4, mean = 0.1339)
# Post (21 choose 5, mean = 0.1518)
# Post (21 choose 6, mean = 0.1696)
# Post (21 choose 7, mean = 0.1875)
# Post (21 choose 8, mean = 0.2054)
# Post (21 choose 9, mean = 0.2232)
# Post (21 choose 10, mean = 0.2411)
# Post (21 choose 11, mean = 0.2589)
# Post (21 choose 12, mean = 0.2768)
# Post (21 choose 13, mean = 0.2946)
# Post (21 choose 14, mean = 0.3125)
# Post (21 choose 15, mean = 0.3304)
# Post (21 choose 16, mean = 0.3482)
# Post (21 choose 17, mean = 0.3661)
# Post (21 choose 18, mean = 0.3839)
# Post (21 choose 19, mean = 0.4018)
# Post (21 choose 20, mean = 0.4196)
# Post (21 choose 21, mean = 0.4375)
# Post (22 choose 1, mean = 0.0789)
# Post (22 choose 2, mean = 0.0965)
# Post (22 choose 3, mean = 0.1140)
# Post (22 choose 4, mean = 0.1316)
# Post (22 choose 5, mean = 0.1491)
# Post (22 choose 6, mean = 0.1667)
# Post (22 choose 7, mean = 0.1842)
# Post (22 choose 8, mean = 0.2018)
# Post (22 choose 9, mean = 0.2193)
# Post (22 choose 10, mean = 0.2368)
# Post (22 choose 11, mean = 0.2544)
# Post (22 choose 12, mean = 0.2719)
# Post (22 choose 13, mean = 0.2895)
# Post (22 choose 14, mean = 0.3070)
# Post (22 choose 15, mean = 0.3246)
# Post (22 choose 16, mean = 0.3421)
# Post (22 choose 17, mean = 0.3596)
# Post (22 choose 18, mean = 0.3772)
# Post (22 choose 19, mean = 0.3947)
# Post (22 choose 20, mean = 0.4123)
# Post (22 choose 21, mean = 0.4298)
# Post (22 choose 22, mean = 0.4474)
# Post (23 choose 1, mean = 0.0776)
# Post (23 choose 2, mean = 0.0948)
# Post (23 choose 3, mean = 0.1121)
# Post (23 choose 4, mean = 0.1293)
# Post (23 choose 5, mean = 0.1466)
# Post (23 choose 6, mean = 0.1638)
# Post (23 choose 7, mean = 0.1810)
# Post (23 choose 8, mean = 0.1983)
# Post (23 choose 9, mean = 0.2155)
# Post (23 choose 10, mean = 0.2328)
# Post (23 choose 11, mean = 0.2500)
# Post (23 choose 12, mean = 0.2672)
# Post (23 choose 13, mean = 0.2845)
# Post (23 choose 14, mean = 0.3017)
# Post (23 choose 15, mean = 0.3190)
# Post (23 choose 16, mean = 0.3362)
# Post (23 choose 17, mean = 0.3534)
# Post (23 choose 18, mean = 0.3707)
# Post (23 choose 19, mean = 0.3879)
# Post (23 choose 20, mean = 0.4052)
# Post (23 choose 21, mean = 0.4224)
# Post (23 choose 22, mean = 0.4397)
# Post (23 choose 23, mean = 0.4569)
# Post (24 choose 1, mean = 0.0763)
# Post (24 choose 2, mean = 0.0932)
# Post (24 choose 3, mean = 0.1102)
# Post (24 choose 4, mean = 0.1271)
# Post (24 choose 5, mean = 0.1441)
# Post (24 choose 6, mean = 0.1610)
# Post (24 choose 7, mean = 0.1780)
# Post (24 choose 8, mean = 0.1949)
# Post (24 choose 9, mean = 0.2119)
# Post (24 choose 10, mean = 0.2288)
# Post (24 choose 11, mean = 0.2458)
# Post (24 choose 12, mean = 0.2627)
# Post (24 choose 13, mean = 0.2797)
# Post (24 choose 14, mean = 0.2966)
# Post (24 choose 15, mean = 0.3136)
# Post (24 choose 16, mean = 0.3305)
# Post (24 choose 17, mean = 0.3475)
# Post (24 choose 18, mean = 0.3644)
# Post (24 choose 19, mean = 0.3814)
# Post (24 choose 20, mean = 0.3983)
# Post (24 choose 21, mean = 0.4153)
# Post (24 choose 22, mean = 0.4322)
# Post (24 choose 23, mean = 0.4492)
# Post (24 choose 24, mean = 0.4661)
# Post (25 choose 1, mean = 0.0750)
# Post (25 choose 2, mean = 0.0917)
# Post (25 choose 3, mean = 0.1083)
# Post (25 choose 4, mean = 0.1250)
# Post (25 choose 5, mean = 0.1417)
# Post (25 choose 6, mean = 0.1583)
# Post (25 choose 7, mean = 0.1750)
# Post (25 choose 8, mean = 0.1917)
# Post (25 choose 9, mean = 0.2083)
# Post (25 choose 10, mean = 0.2250)
# Post (25 choose 11, mean = 0.2417)
# Post (25 choose 12, mean = 0.2583)
# Post (25 choose 13, mean = 0.2750)
# Post (25 choose 14, mean = 0.2917)
# Post (25 choose 15, mean = 0.3083)
# Post (25 choose 16, mean = 0.3250)
# Post (25 choose 17, mean = 0.3417)
# Post (25 choose 18, mean = 0.3583)
# Post (25 choose 19, mean = 0.3750)
# Post (25 choose 20, mean = 0.3917)
# Post (25 choose 21, mean = 0.4083)
# Post (25 choose 22, mean = 0.4250)
# Post (25 choose 23, mean = 0.4417)
# Post (25 choose 24, mean = 0.4583)
# Post (25 choose 25, mean = 0.4750)
# Post (26 choose 1, mean = 0.0738)
# Post (26 choose 2, mean = 0.0902)
# Post (26 choose 3, mean = 0.1066)
# Post (26 choose 4, mean = 0.1230)
# Post (26 choose 5, mean = 0.1393)
# Post (26 choose 6, mean = 0.1557)
# Post (26 choose 7, mean = 0.1721)
# Post (26 choose 8, mean = 0.1885)
# Post (26 choose 9, mean = 0.2049)
# Post (26 choose 10, mean = 0.2213)
# Post (26 choose 11, mean = 0.2377)
# Post (26 choose 12, mean = 0.2541)
# Post (26 choose 13, mean = 0.2705)
# Post (26 choose 14, mean = 0.2869)
# Post (26 choose 15, mean = 0.3033)
# Post (26 choose 16, mean = 0.3197)
# Post (26 choose 17, mean = 0.3361)
# Post (26 choose 18, mean = 0.3525)
# Post (26 choose 19, mean = 0.3689)
# Post (26 choose 20, mean = 0.3852)
# Post (26 choose 21, mean = 0.4016)
# Post (26 choose 22, mean = 0.4180)
# Post (26 choose 23, mean = 0.4344)
# Post (26 choose 24, mean = 0.4508)
# Post (26 choose 25, mean = 0.4672)
# Post (26 choose 26, mean = 0.4836)
# Post (27 choose 1, mean = 0.0726)
# Post (27 choose 2, mean = 0.0887)
# Post (27 choose 3, mean = 0.1048)
# Post (27 choose 4, mean = 0.1210)
# Post (27 choose 5, mean = 0.1371)
# Post (27 choose 6, mean = 0.1532)
# Post (27 choose 7, mean = 0.1694)
# Post (27 choose 8, mean = 0.1855)
# Post (27 choose 9, mean = 0.2016)
# Post (27 choose 10, mean = 0.2177)
# Post (27 choose 11, mean = 0.2339)
# Post (27 choose 12, mean = 0.2500)
# Post (27 choose 13, mean = 0.2661)
# Post (27 choose 14, mean = 0.2823)
# Post (27 choose 15, mean = 0.2984)
# Post (27 choose 16, mean = 0.3145)
# Post (27 choose 17, mean = 0.3306)
# Post (27 choose 18, mean = 0.3468)
# Post (27 choose 19, mean = 0.3629)
# Post (27 choose 20, mean = 0.3790)
# Post (27 choose 21, mean = 0.3952)
# Post (27 choose 22, mean = 0.4113)
# Post (27 choose 23, mean = 0.4274)
# Post (27 choose 24, mean = 0.4435)
# Post (27 choose 25, mean = 0.4597)
# Post (27 choose 26, mean = 0.4758)
# Post (27 choose 27, mean = 0.4919)
# Post (28 choose 1, mean = 0.0714)
# Post (28 choose 2, mean = 0.0873)
# Post (28 choose 3, mean = 0.1032)
# Post (28 choose 4, mean = 0.1190)
# Post (28 choose 5, mean = 0.1349)
# Post (28 choose 6, mean = 0.1508)
# Post (28 choose 7, mean = 0.1667)
# Post (28 choose 8, mean = 0.1825)
# Post (28 choose 9, mean = 0.1984)
# Post (28 choose 10, mean = 0.2143)
# Post (28 choose 11, mean = 0.2302)
# Post (28 choose 12, mean = 0.2460)
# Post (28 choose 13, mean = 0.2619)
# Post (28 choose 14, mean = 0.2778)
# Post (28 choose 15, mean = 0.2937)
# Post (28 choose 16, mean = 0.3095)
# Post (28 choose 17, mean = 0.3254)
# Post (28 choose 18, mean = 0.3413)
# Post (28 choose 19, mean = 0.3571)
# Post (28 choose 20, mean = 0.3730)
# Post (28 choose 21, mean = 0.3889)
# Post (28 choose 22, mean = 0.4048)
# Post (28 choose 23, mean = 0.4206)
# Post (28 choose 24, mean = 0.4365)
# Post (28 choose 25, mean = 0.4524)
# Post (28 choose 26, mean = 0.4683)
# Post (28 choose 27, mean = 0.4841)
# Post (28 choose 28, mean = 0.5000)

# %% [markdown]
# It would need 28/28 participants who would mix to change the believe of Heidi such that she thinks 50% of all people mix their puré.

# %% [markdown]
# # Exercise 3
#
# ![Beta-Mean](./Exercise-3a.png)
#
# ![Beta-as-Weighted-Sum-Part1](./Exercise-3b1.png)
# ![Beta-as-Weighted-Sum-Part2](./Exercise-3b2.png)
